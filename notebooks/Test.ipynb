# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd

# %%
# Base URLs from the readme.
urlbase_2019 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_2018 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_2017 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_2016 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2019 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2018 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2017 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2016 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='

# %%
# Page numbers given in the ReadMe.
pgs_2016 = 154
pgs_2017 = 147
pgs_2018 = 85
pgs_2019 = 113

pgs_half_2016 = 898
pgs_half_2017 = 892
pgs_half_2018 = 598
pgs_half_2019 = 690

# %%
# Test pull from www.rocknroll.com
website_url = urlbase_2019
page = 2
response = requests.post(website_url + str(page))

response.status_code # 200 HTTP code means a successful request.
# Out:
# 200

# %%
# Checking what we got back.
print(type(response))
response.content
# Out:
# <class 'requests.models.Response'>
# b'\n<!DOCTYPE html>\n<!--[if IE 9]><html lang="en" class="ie9 no-js"><![endif]-->\n<!--[if !IE]><!-->\n<html lang="en">\n<!--<![endif]-->\n<head>\n<script src="/cdn-cgi/apps/head/u7S6kWy3Cysuih2qEtS0XdJlwiE.js"></script><link href="/styles/vendor.min.css" rel="stylesheet" />\n<link href="/styles/rnr.min.css" rel="stylesheet" />\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta http-equiv="Content-type" content="text/html; charset=utf-8">\n<meta content="width=device-width, initial-scale=1.0" name="viewport" />\n<title> | Rock n Roll Marathon Series | Marathon Half Marathon Events</title>\n<meta property="og:title" content="" />\n<meta property="og:image" content="" />\n<meta property="og:description" content="" />\n<meta property="og:url" content="https://www.runrocknroll.com:443/en/Events/Nashville/The Races/Marathon/2019 Results" />\n\n<script>\r\n        (function (w, d, s, l, i) {\r\n            w[l] = w[l] || [];\r\n            w[l].push({\r\n                \'gtm.start\':\r\n                    new Date().getTime(),\r\n                event: \'gtm.js\'\r\n            });\r\n            var f = d.getElementsByTagName(s)[0],\r\n                j = d.createElement(s),\r\n                dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\r\n            j.async = true;\r\n            j.src =\r\n                \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\r\n            f.parentNode.insertBefore(j, f);\r\n        })(window, document, \'script\', \'dataLayer\', \'GTM-MFKTKL\');\r\n    </script>\n\n\n<script type="text/javascript">\r\n        (function () {\r\n            var didInit = false;\r\n            function initMunchkin() {\r\n                if (didInit === false) {\r\n                    didInit = true;\r\n                    Munchkin.init(\'124-QVG-738\');\r\n                }\r\n            }\r\n            var s = document.createElement(\'script\');\r\n            s.type = \'text/javascript\';\r\n            s.async = true;\r\n            s.src = \'//munchkin.marketo.net/munchkin.js\';\r\n            s.onreadystatechange = function () {\r\n                if (this.readyState == \'complete\' || this.readyState == \'loaded\') {\r\n                    initMunchkin();\r\n                }\r\n            };\r\n            s.onload = initMunchkin;\r\n            document.getElementsByTagName(\'head\')[0].appendChild(s);\r\n        })();\r\n    </script>\n\n\n<script src="/scripts/Sitecore.Foundation.Frameworks.min.js"></script>\n<script src="/scripts/Sitecore.Foundation.Theming.min.js"></script>\n</head>\n<body class="header-static ">\n\n<noscript>\r\n        <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MFKTKL"\r\n                height="0" width="0" style="display:none;visibility:hidden"></iframe>\r\n    </noscript>\n\n<div id="main-container">\n<header class="header-static">\n<nav class="navbar navbar-default navbar-static" id="mainNavbar">\n<div class="container">\n<div class="row">\n<div class="nav-wrapper">\n<div class="navbar-right col-sm-12 col-md-2 col-lg-2 clearfix">\n<div class="navbar-activity event-navbar-activity">\n<ul class="nav navbar-nav">\n<li class="dropdown">\n<a href="#" class="btn dropdown-toggle" data-toggle="dropdown">\n<i class="fa fa-globe"></i>\n</a>\n<ul class="dropdown-menu">\n<li class="">\n<a href="https://www.runrocknroll.com:443/it/events/nashville/the races/marathon/2019 results/" onclick="return SwitchToLanguage(\'it\', \'en\', \'https://www.runrocknroll.com:443/it/events/nashville/the races/marathon/2019 results/\')">italiano</a>\n</li>\n<li class="">\n<a href="https://www.runrocknroll.com:443/zh/events/nashville/the races/marathon/2019 results/" onclick="return SwitchToLanguage(\'zh\', \'en\', \'https://www.runrocknroll.com:443/zh/events/nashville/the races/marathon/2019 results/\')">\xe4\xb8\xad\xe6\x96\x87</a>\n</li>\n<li class="active">\n<a href="https://www.runrocknroll.com:443/en/events/nashville/the races/marathon/201 ...

# %%
# Using BeautifulSoup to read content.
soup = BeautifulSoup(response.content, 'lxml')
print(soup.title)
# Out:
# <title> | Rock n Roll Marathon Series | Marathon Half Marathon Events</title>

# %%
# Just pulling the section of the page we are looking for. 'table table-responsive table-bordered' found by
# inspecting the webpage in browser and finding where table start in the HTML.
tables = soup.find_all('table', attrs = {'class': 'table table-responsive table-bordered'})
tables
# Out:
# [<table class="table table-responsive table-bordered">
#  <tr>
#  <th class="table-place">Overall</th>
#  <th class="table-place">Bib</th>
#  <th class="table-name">Name</th>
#  <th class="table-time">Time</th>
#  </tr>
#  <tr>
#  <td>26</td>
#  <td>33054</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=33054">Nixon Gutierrez</a></td>
#  <td>03:06:05</td>
#  </tr>
#  <tr>
#  <td>27</td>
#  <td>30120</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30120">Jeff Vinciguerra</a></td>
#  <td>03:06:11</td>
#  </tr>
#  <tr>
#  <td>28</td>
#  <td>33058</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=33058">Matthew Katz</a></td>
#  <td>03:06:21</td>
#  </tr>
#  <tr>
#  <td>29</td>
#  <td>30002</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30002">Carson Davis</a></td>
#  <td>03:06:25</td>
#  </tr>
#  <tr>
#  <td>30</td>
#  <td>30061</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30061">Willy Mcnamara</a></td>
#  <td>03:07:05</td>
#  </tr>
#  <tr>
#  <td>31</td>
#  <td>30119</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30119">Jeffrey Suppinger</a></td>
#  <td>03:07:41</td>
#  </tr>
#  <tr>
#  <td>32</td>
#  <td>7</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=7">Leah Frazier Allen</a></td>
#  <td>03:07:51</td>
#  </tr>
#  <tr>
#  <td>33</td>
#  <td>30513</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30513">Emily Soppe</a></td>
#  <td>03:11:16</td>
#  </tr>
#  <tr>
#  <td>34</td>
#  <td>32300</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=32300">Anthony Jackson</a></td>
#  <td>03:11:30</td>
#  </tr>
#  <tr>
#  <td>35</td>
#  <td>30138</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30138">Gregg Lamb</a></td>
#  <td>03:11:59</td>
#  </tr>
#  <tr>
#  <td>36</td>
#  <td>33055</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=33055">Caleb Chambers</a></td>
#  <td>03:12:24</td>
#  </tr>
#  <tr>
#  <td>37</td>
#  <td>30046</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30046">Josh Einspahr</a></td>
#  <td>03:12:40</td>
#  </tr>
#  <tr>
#  <td>38</td>
#  <td>30282</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30282">Bryan Curtin</a></td>
#  <td>03:13:20</td>
#  </tr>
#  <tr>
#  <td>39</td>
#  <td>30055</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30055">Jason Schwab</a></td>
#  <td>03:13:22</td>
#  </tr>
#  <tr>
#  <td>40</td>
#  <td>30180</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30180">Steve Troxel</a></td>
#  <td>03:13:58</td>
#  </tr>
#  <tr>
#  <td>41</td>
#  <td>30145</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30145">David Burton</a></td>
#  <td>03:14:24</td>
#  </tr>
#  <tr>
#  <td>42</td>
#  <td>33195</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=33195">Scott Slavens</a></td>
#  <td>03:15:06</td>
#  </tr>
#  <tr>
#  <td>43</td>
#  <td>30124</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30124">Allison Koch</a></td>
#  <td>03:15:27</td>
#  </tr>
#  <tr>
#  <td>44</td>
#  <td>30210</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30210">Richard Sanzone</a></td>
#  <td>03:15:38</td>
#  </tr>
#  <tr>
#  <td>45</td>
#  <td>30149</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30149">Alan Arpon</a></td>
#  <td>03:15:42</td>
#  </tr>
#  <tr>
#  <td>46</td>
#  <td>33203</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=33203">Remington Ponce-Pore</a></td>
#  <td>03:15:49</td>
#  </tr>
#  <tr>
#  <td>47</td>
#  <td>30259</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30259">Tara Austin</a></td>
#  <td>03:15:54</td>
#  </tr>
#  <tr>
#  <td>48</td>
#  <td>30179</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30179">Cyrille Tiberghien</a></td>
#  <td>03:15:57</td>
#  </tr>
#  <tr>
#  <td>49</td>
#  <td>30097</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30097">David Long</a></td>
#  <td>03:17:04</td>
#  </tr>
#  <tr>
#  <td>50</td>
#  <td>31210</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=31210">David Quiroga</a></td>
#  <td>03:18:39</td>
#  </tr>
#  </table>,
#  <table class="table table-responsive table-bordered">
#  <tr>
#  <th class="table-header" colspan="3">Top Females</th>
#  </tr>
#  <tr>
#  <th class="table-place">Gender PL</th>
#  <th class="table-name">Name</th>
#  <th class="table-time">Time</th>
#  </tr>
#  <tr>
#  <td>1</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30002">Carson Davis</a></td>
#  <td>03:06:25</td>
#  </tr>
#  <tr>
#  <td>2</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=7">Leah Frazier Allen</a></td>
#  <td>03:07:51</td>
#  </tr>
#  <tr>
#  <td>3</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30513">Emily Soppe</a></td>
#  <td>03:11:16</td>
#  </tr>
#  <tr>
#  <td>4</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30124">Allison Koch</a></td>
#  <td>03:15:27</td>
#  </tr>
#  <tr>
#  <td>5</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30259">Tara Austin</a></td>
#  <td>03:15:54</td>
#  </tr>
#  <tr>
#  <td>6</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30322">Lisa Holding Eagle</a></td>
#  <td>03:21:37</td>
#  </tr>
#  <tr>
#  <td>7</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30379">Rachel Polk</a></td>
#  <td>03:22:05</td>
#  </tr>
#  <tr>
#  <td>8</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30233">Amanda Jackson</a></td>
#  <td>03:25:15</td>
#  </tr>
#  <tr>
#  <td>9</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30126">Marissa Mchugh</a></td>
#  <td>03:25:29</td>
#  </tr>
#  <tr>
#  <td>10</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30400">Jessica Spicola</a></td>
#  <td>03:25:43</td>
#  </tr>
#  </table>,
#  <table class="table table-responsive table-bordered">
#  <tr>
#  <th class="table-header" colspan="3">Top Men</th>
#  </tr>
#  <tr>
#  <th class="table-place">Gender PL</th>
#  <th class="table-name">Name</th>
#  <th class="table-time">Time</th>
#  </tr>
#  <tr>
#  <td>2</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=1">Scott Wietecha</a></td>
#  <td>02:34:59</td>
#  </tr>
#  <tr>
#  <td>3</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=4">Jordan Wilson</a></td>
#  <td>02:35:24</td>
#  </tr>
#  <tr>
#  <td>4</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30034">Steelton Flynn</a></td>
#  <td>02:39:59</td>
#  </tr>
#  <tr>
#  <td>5</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30035">Thomas Ellis</a></td>
#  <td>02:42:09</td>
#  </tr>
#  <tr>
#  <td>6</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=33172">Nicholas Tseffos</a></td>
#  <td>02:48:42</td>
#  </tr>
#  <tr>
#  <td>7</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30053">Satoshi Mitsumori</a></td>
#  <td>02:50:33</td>
#  </tr>
#  <tr>
#  <td>8</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30051">Harrison Kieffer</a></td>
#  <td>02:51:18</td>
#  </tr>
#  <tr>
#  <td>9</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30086">Steven Forte</a></td>
#  <td>02:54:34</td>
#  </tr>
#  <tr>
#  <td>10</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30042">Grant Rice</a></td>
#  <td>02:55:49</td>
#  </tr>
#  <tr>
#  <td>11</td>
#  <td><a href="/en/Events/Nashville/The-Races/Marathon/2019-Results/Athlete?id=30049">Andrew Fisher</a></td>
#  <td>02:56:05</td>
#  </tr>
#  </table>]

# %%
type(tables)
# Out:
# bs4.element.ResultSet

# %%
len(tables)
# Out:
# 3

# %%
# Turning the request into a list through Pandas.
result_list = pd.read_html(str(tables[0]))
len(result_list)
# Out:
# 1

# %%
type(result_list)
# Out:
# list

# %%
# Turning the list into a DataFrame.
first_try = result_list[0]
first_try
# Out:
#     Overall    Bib                  Name      Time
# 0        26  33054       Nixon Gutierrez  03:06:05
# 1        27  30120      Jeff Vinciguerra  03:06:11
# 2        28  33058          Matthew Katz  03:06:21
# 3        29  30002          Carson Davis  03:06:25
# 4        30  30061        Willy Mcnamara  03:07:05
# 5        31  30119     Jeffrey Suppinger  03:07:41
# 6        32      7    Leah Frazier Allen  03:07:51
# 7        33  30513           Emily Soppe  03:11:16
# 8        34  32300       Anthony Jackson  03:11:30
# 9        35  30138            Gregg Lamb  03:11:59
# 10       36  33055        Caleb Chambers  03:12:24
# 11       37  30046         Josh Einspahr  03:12:40
# 12       38  30282          Bryan Curtin  03:13:20
# 13       39  30055          Jason Schwab  03:13:22
# 14       40  30180          Steve Troxel  03:13:58
# 15       41  30145          David Burton  03:14:24
# 16       42  33195         Scott Slavens  03:15:06
# 17       43  30124          Allison Koch  03:15:27
# 18       44  30210       Richard Sanzone  03:15:38
# 19       45  30149            Alan Arpon  03:15:42
# 20       46  33203  Remington Ponce-Pore  03:15:49
# 21       47  30259           Tara Austin  03:15:54
# 22       48  30179    Cyrille Tiberghien  03:15:57
# 23       49  30097            David Long  03:17:04
# 24       50  31210         David Quiroga  03:18:39

# %%
type(first_try)
# Out:
# pandas.core.frame.DataFrame
